# %%
import numpy as np
import matplotlib.pyplot as plt


n = 1000
d = []
lista = []
for i in range(0,8):
    mensaje = 'archivo'
    mensaje += str(i)
    #data = np.loadtxt(mensaje)
    data = np.random.randint(1,101,n)/100
    np.concatenate((d, data), axis=None)
    plt.figure()
    plt.hist(data, bins='auto')
    plt.show()
    lista.append(data)

#ahora Gelman Rubin
M = 8
N = 1000
for i in range(0,8):
    dato = lista[i]
    B = N/(M-N)
    B = B*(sum(dato-np.mean(dato)))
    W = 1/M
    ds = 1
    W = W*np.sum(np.mean(dato)**2)
    part1 = (ds+3)/(ds+1)
    part2 = ((N-1)/N)*W
    part3 = ((M+1)/(M*N))*B
    V= part2 + part3
    R = (part1*(part2/part3))**0.5
    print(R)
# Out:
# nan
# nan
# 41535311.28600881
# 31056185.214921378
# 41423844.9415015
# 40228725.91883862
# 30737201.995434564
# 86615255.52663276
# /srv/conda/lib/python3.6/site-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in double_scalars
